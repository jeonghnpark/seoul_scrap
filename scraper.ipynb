# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
api_key = os.getenv("SEOUL_API_KEY")
api_key
# Out:
# '666d79594e6a683734397563505269'

# %%
BASE_URL = "http://openAPI.seoul.go.kr:8088"
url =
